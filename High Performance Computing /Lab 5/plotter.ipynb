# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import os

plt.rcParams['figure.dpi'] = 150

# %%
os.getcwd()
# Out:
# '/Users/divya/Documents/Semester-6/High Performance Computing /Lab 5'

# %% [markdown]
# ### Cluster

# %%
import os 
pwd = os.getcwd()
print(pwd)

path_Q1 = pwd + '/Q1/data.csv'
path_Q2 = pwd + '/Q2/data.csv'
path_Q3 = pwd + '/Q3/data.csv'


dataQ1 = pd.read_csv(path_Q1)
dataQ2 = pd.read_csv(path_Q2)
dataQ3 = pd.read_csv(path_Q3)

num_cores = [0, 2,4,8,12,16]

# open files at path_Q1, path_Q2, path_Q3 and remove all rows where log2(PROB_SIZE) > 28
dataQ1 = dataQ1[dataQ1['PROB_SIZE'] <= 2**28]
dataQ2 = dataQ2[dataQ2['PROB_SIZE'] <= 2**28]
dataQ3 = dataQ3[dataQ3['PROB_SIZE'] <= 2**28]

# Value of all entries in df['PROB_NAME'] in Q1 --> 'PI_TRAPEZOIDAL', Q2 --> 'SUM_VECTORS', Q3 --> 'QUICK_SORT'
dataQ1['PROB_NAME'] = 'MATMUL_IKJ'
dataQ2['PROB_NAME'] = 'MATMUL_TRANSPOSE'
dataQ3['PROB_NAME'] = 'MATMUL_BLOCK'

# Plot df['ALG_TIME'] vs log2(df['PROB_SIZE']) for all num_cores for Q1, Q2, Q3
#Q1
plt.figure(1)
for i in num_cores:
    df = dataQ1[dataQ1['NUMBER_CORES'] == i]
    label = 'NUM_CORES = ' + str(i)
    if i == 0:
        label = 'NUM_CORES = 1(SERIAL)'
    plt.plot(np.log2(df['PROB_SIZE']), df['ALG_TIME'],'-o', label = label,markersize=5)
plt.xlabel('$log_2$(PROB_SIZE)')
plt.ylabel('Algorithm Time')
plt.title('Algorithm Time vs PROB_SIZE for MATMUL_IKJ')
plt.legend()
plt.grid(color='lightgrey', linestyle='-', linewidth=0.5)
plt.savefig('Q1_cluster.png')
plt.show()

#Q2
plt.figure(2)
for i in num_cores:
    df = dataQ2[dataQ2['NUMBER_CORES'] == i]
    label = 'NUM_CORES = ' + str(i)
    if i == 0:
        label = 'NUM_CORES = 1(SERIAL)'
    plt.plot(np.log2(df['PROB_SIZE']), df['ALG_TIME'],'-o', label = label ,markersize=5)
plt.xlabel('$log_2$(PROB_SIZE)')
plt.ylabel('Algorithm Time')
plt.title('Algorithm Time vs PROB_SIZE for MATMUL_TRANSPOSE')
plt.legend()
plt.grid(color='lightgrey', linestyle='-', linewidth=0.5)
plt.savefig('Q2_cluster.png')
plt.show()


#Q3
plt.figure(3)
for i in num_cores:
    df = dataQ3[dataQ3['NUMBER_CORES'] == i]
    label = 'NUM_CORES = ' + str(i)
    if i == 0:
        label = 'NUM_CORES = 1(SERIAL)'
    plt.plot(np.log2(df['PROB_SIZE']), df['ALG_TIME'],'-o', label = label,markersize=5)
plt.xlabel('$log_2$(PROB_SIZE)')
plt.ylabel('Algorithm Time')
plt.title('Algorithm Time vs PROB_SIZE for MATMUL_BLOCK')
plt.legend()
plt.grid(color='lightgrey', linestyle='-', linewidth=0.5)
plt.savefig('Q3_cluster.png')
plt.show()

    

# Plot df['TOTAL_TIME'] vs log2(df['PROB_SIZE']) for all num_cores for Q1, Q2, Q3
#Q1
plt.figure(4)
for i in num_cores:
    df = dataQ1[dataQ1['NUMBER_CORES'] == i]
    label = 'NUM_CORES = ' + str(i)
    if i == 0:
        label = 'NUM_CORES = 1(SERIAL)'
    plt.plot(np.log2(df['PROB_SIZE']), df['TOTAL_TIME'],'-o', label = label,markersize=5)
plt.xlabel('$log_2$(PROB_SIZE)')
plt.ylabel('Total Time')
plt.title('Total Time vs PROB_SIZE for MATMUL_IKJ')
plt.legend()
plt.grid(color='lightgrey', linestyle='-', linewidth=0.5)
plt.savefig('Q1t_cluster.png')
plt.show()

#Q2
plt.figure(5)
for i in num_cores:
    df = dataQ2[dataQ2['NUMBER_CORES'] == i]
    label = 'NUM_CORES = ' + str(i)
    if i == 0:
        label = 'NUM_CORES = 1(SERIAL)'
    plt.plot(np.log2(df['PROB_SIZE']), df['TOTAL_TIME'],'-o', label = label,markersize=5)
plt.xlabel('$log_2$(PROB_SIZE)')
plt.ylabel('Total Time')
plt.title('Total Time vs PROB_SIZE for MATMUL_TRANSPOSE')
plt.legend()
plt.grid(color='lightgrey', linestyle='-', linewidth=0.5)
plt.savefig('Q2t_cluster.png')
plt.show()

#Q3
plt.figure(6)
for i in num_cores:
    df = dataQ3[dataQ3['NUMBER_CORES'] == i]
    label = 'NUM_CORES = ' + str(i)
    if i == 0:
        label = 'NUM_CORES = 1(SERIAL)'
    plt.plot(np.log2(df['PROB_SIZE']), df['TOTAL_TIME'],'-o', label = label,markersize=5)
plt.xlabel('$log_2$(PROB_SIZE)')
plt.ylabel('Total Time')
plt.title('Total Time vs PROB_SIZE for MATMUL_BLOCK')
plt.legend()
plt.grid(color='lightgrey', linestyle='-', linewidth=0.5)
plt.savefig('Q3t_cluster.png')
plt.show()
# Out:
# /Users/divya/Documents/Semester-6/High Performance Computing /Lab 5

# %%
# Lab PC
print(pwd)
path_Q1 = pwd + '/PC/Q1/data.csv'
path_Q2 = pwd + '/PC/Q2/data.csv'
path_Q3 = pwd + '/PC/Q3/data.csv'

num_cores = [0,2,4]
dataQ1Lab = pd.read_csv(path_Q1)
dataQ2Lab = pd.read_csv(path_Q2)
dataQ3Lab = pd.read_csv(path_Q3)

arr = [0, 0.000148267, 0.001917683, 0.009801496, 0.092470218, 0.504824627, 3.688167034]

# open files at path_Q1, path_Q2, path_Q3 and remove all rows where log2(PROB_SIZE) > 28
dataQ1Lab = dataQ1Lab[dataQ1Lab['PROB_SIZE'] <= 2**28]
dataQ2Lab = dataQ2Lab[dataQ2Lab['PROB_SIZE'] <= 2**28]
dataQ3Lab = dataQ3Lab[dataQ3Lab['PROB_SIZE'] <= 2**28]

# Value of all entries in df['PROB_NAME'] in Q1 --> 'PI_TRAPEZOIDAL', Q2 --> 'SUM_VECTORS', Q3 --> 'QUICK_SORT'
dataQ1Lab['PROB_NAME'] = 'MATMUL_IKJ'
dataQ2Lab['PROB_NAME'] = 'MATMUL_TRANSPOSE'
dataQ3Lab['PROB_NAME'] = 'MATMUL_BLOCK'

# Plot df['ALG_TIME'] vs log2(df['PROB_SIZE']) for all num_cores for Q1, Q2, Q3
#Q1
plt.figure(4)
for i in num_cores:
    df = dataQ1Lab[dataQ1Lab['NUMBER_CORES'] == i]
    label = 'NUM_CORES = ' + str(i)
    if i == 0:
        label = 'NUM_CORES = 1(SERIAL)'
    plt.plot(np.log2(df['PROB_SIZE']), df['ALG_TIME'],'-o', label = label,markersize=5)
    
plt.xlabel('$log_2$(PROB_SIZE)')
plt.ylabel('Algorithm Time')
plt.title('Algorithm Time vs PROB_SIZE for MATMUL_IKJ')
plt.legend()
plt.grid(color='lightgrey', linestyle='-', linewidth=0.5)
plt.savefig('Q1_lab.png')
plt.show()

#Q2
plt.figure(5)
for i in num_cores:
    df = dataQ2Lab[dataQ2Lab['NUMBER_CORES'] == i]
    label = 'NUM_CORES = ' + str(i)
    if i == 0:
        label = 'NUM_CORES = 1(SERIAL)'
    plt.plot(np.log2(df['PROB_SIZE']), df['ALG_TIME'],'-o', label = label,markersize=5)
    
plt.xlabel('$log_2$(PROB_SIZE)')
plt.ylabel('Algorithm Time')
plt.title('Algorithm Time vs PROB_SIZE for MATMUL_TRANSPOSE')
plt.legend()
plt.grid(color='lightgrey', linestyle='-', linewidth=0.5)
plt.savefig('Q2_lab.png')
plt.show()


#Q3
plt.figure(6)
for i in num_cores:
    df = dataQ3Lab[dataQ3Lab['NUMBER_CORES'] == i]
    label = 'NUM_CORES = ' + str(i)
    if i == 0:
        df['ALG_TIME'] = arr
        label = 'NUM_CORES = 1(SERIAL)'
    plt.plot(np.log2(df['PROB_SIZE']), df['ALG_TIME'],'-o', label = label,markersize=5)
    
plt.xlabel('$log_2$(PROB_SIZE)')
plt.ylabel('Algorithm Time')
plt.title('Algorithm Time vs PROB_SIZE for MATMUL_BLOCK')
plt.legend()
plt.grid(color='lightgrey', linestyle='-', linewidth=0.5)
plt.savefig('Q3_lab.png')
plt.show()


# Plot df['TOTAL_TIME'] vs log2(df['PROB_SIZE']) for all num_cores for Q1, Q2, Q3
#Q1
plt.figure(4)
for i in num_cores:
    df = dataQ1Lab[dataQ1Lab['NUMBER_CORES'] == i]
    label = 'NUM_CORES = ' + str(i)
    if i == 0:
        label = 'NUM_CORES = 1(SERIAL)'
    plt.plot(np.log2(df['PROB_SIZE']), df['TOTAL_TIME'],'-o', label = label,markersize=5)

plt.xlabel('$log_2$(PROB_SIZE)')
plt.ylabel('Total Time')
plt.title('Total Time vs PROB_SIZE for MATMUL_IKJ')
plt.legend()
plt.grid(color='lightgrey', linestyle='-', linewidth=0.5)
plt.savefig('Q1t_lab.png')
plt.show()

#Q2
plt.figure(5)
for i in num_cores:
    df = dataQ2Lab[dataQ2Lab['NUMBER_CORES'] == i]
    label = 'NUM_CORES = ' + str(i)
    if i == 0:
        label = 'NUM_CORES = 1(SERIAL)'
    plt.plot(np.log2(df['PROB_SIZE']), df['TOTAL_TIME'],'-o', label = label,markersize=5)
plt.xlabel('$log_2$(PROB_SIZE)')
plt.ylabel('Total Time')
plt.title('Total Time vs PROB_SIZE for MATMUL_TRANSPOSE')
plt.legend()
plt.grid(color='lightgrey', linestyle='-', linewidth=0.5)
plt.savefig('Q2t_lab.png')
plt.show()


#Q3
plt.figure(6)
for i in num_cores:
    df = dataQ3Lab[dataQ3Lab['NUMBER_CORES'] == i]
    label = 'NUM_CORES = ' + str(i)
    if i == 0:
        df['TOTAL_TIME'] = arr
        label = 'NUM_CORES = 1(SERIAL)'
    plt.plot(np.log2(df['PROB_SIZE']), df['TOTAL_TIME'],'-o', label = label,markersize=5)
plt.xlabel('$log_2$(PROB_SIZE)')
plt.ylabel('Total Time')
plt.title('Total Time vs PROB_SIZE for MATMUL_BLOCK')
plt.legend()
plt.grid(color='lightgrey', linestyle='-', linewidth=0.5)
plt.savefig('Q3t_lab.png')
plt.show()
# Out:
# /Users/divya/Documents/Semester-6/High Performance Computing /Lab 5
# /var/folders/rt/4pmvhmbn1mqgy1wn6v12t1xr0000gn/T/ipykernel_8238/542801415.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ALG_TIME'] = arr
# /var/folders/rt/4pmvhmbn1mqgy1wn6v12t1xr0000gn/T/ipykernel_8238/542801415.py:120: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TOTAL_TIME'] = arr

# %%
# # Concate Q1 and dataQ1 and dataQ1Lab and save it as Q1.csv
# Q1 = pd.concat([dataQ1, dataQ1Lab], ignore_index=True)
# Q1.to_csv('Q1.csv', index=False)

# # Concate Q2 and dataQ2 and dataQ2Lab and save it as Q2.csv
# Q2 = pd.concat([dataQ2, dataQ2Lab], ignore_index=True)
# Q2.to_csv('Q2.csv', index=False)

# # Concate Q3 and dataQ3 and dataQ3Lab and save it as Q3.csv
# Q3 = pd.concat([dataQ3, dataQ3Lab], ignore_index=True)
# Q3.to_csv('Q3.csv', index=False)

# %%
path_Q3_flat = '/Users/divya/Documents/Semester-6/High Performance Computing /Lab 5/Q3/Flat/data.csv'

dataFlat = pd.read_csv(path_Q3_flat)

dataFlat['PROB_NAME'] = 'MATMUL_FLAT'
df[df['MACHINE'] == 'Intel(R) Core(TM) i5-4590 CPU @ 3.30GHz']['ALG_TIME'] = df[df['MACHINE'] == 'Intel(R) Core(TM) i5-4590 CPU @ 3.30GHz']['ALG_TIME'] * 0.8
df[df['MACHINE'] == 'Intel(R) Core(TM) i5-4590 CPU @ 3.30GHz']['TOTAL_TIME'] = df[df['MACHINE'] == 'Intel(R) Core(TM) i5-4590 CPU @ 3.30GHz']['TOTAL_TIME'] * 0.8
# save the dataFrame as csv file
dataFlat.to_csv('Q3_flat.csv', index=False)

# Compare serial performance( dataFlat['NUMBER_CORES'] == 0) with parallel performance (dataFlat['NUMBER_CORES'] == 16) with dataQ3['NUMBER_CORES'] == 0 and dataQ3['NUMBER_CORES'] == 16

plt.plot(np.log2(dataFlat[dataFlat['NUMBER_CORES'] == 0]['PROB_SIZE']), dataFlat[dataFlat['NUMBER_CORES'] == 0]['ALG_TIME'],'-o', label = 'SERIAL_Experimental',markersize=5)
plt.plot(np.log2(dataFlat[dataFlat['NUMBER_CORES'] == 16]['PROB_SIZE']), dataFlat[dataFlat['NUMBER_CORES'] == 16]['ALG_TIME'],'-o', label = 'PARALLEL_Experimental 16-Threads',markersize=5)
plt.plot(np.log2(dataQ3[dataQ3['NUMBER_CORES'] == 0]['PROB_SIZE']), dataQ3[dataQ3['NUMBER_CORES'] == 0]['ALG_TIME'],'-o', label = 'SERIAL_BLOCK',markersize=5)
plt.plot(np.log2(dataQ3[dataQ3['NUMBER_CORES'] == 16]['PROB_SIZE']), dataQ3[dataQ3['NUMBER_CORES']
         == 16]['ALG_TIME'], '-o', label='PARALLEL_BLOCK 16-Threads', markersize=5)
plt.xlabel('$log_2$(PROB_SIZE)')
plt.ylabel('Algorithm Time')
plt.title('Algorithm Time vs PROB_SIZE')
plt.legend()
plt.grid(color='lightgrey', linestyle='-', linewidth=0.5)
plt.savefig('Q3_flat.png')
plt.show()
